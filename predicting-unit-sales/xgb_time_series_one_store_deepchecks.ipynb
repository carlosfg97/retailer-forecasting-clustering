# %%
import pandas as pd
# import dask.dataframe as dd
from datetime import datetime
from numpy import mean, std
from sklearn.model_selection import cross_val_score, RepeatedKFold
from xgboost import XGBRegressor, plot_importance
# import shap

# %%
data_path = '/Users/tehuttesfayebiru/Downloads'

# %%
# import mlflow

# remote_server_uri = "databricks" # set to your server URI
# mlflow.set_tracking_uri(remote_server_uri)
# mlflow.set_experiment("/my-experiment")

# %%
sales = pd.read_csv(f'{data_path}/family_stores_unit_sales.csv').sort_values(by=['year_week', 'family'])
print(sales.shape)
sales.head()
# Out:
# (12672, 5)
#             family  store_nbr  year_week  unit_sales type
# 0        BEVERAGES         10     201301      4349.0    C
# 4302     BEVERAGES         27     201301     10020.0    D
# 7120     BEVERAGES         43     201301     12950.0    E
# 9854     BEVERAGES         46     201301     24198.0    A
# 243   BREAD/BAKERY         10     201301       781.0    C

# %%
sales['type'].unique()
# Out:
# array(['C', 'D', 'E', 'A', 'B'], dtype=object)

# %%
family = 'GROCERY I'
store_type = 'E'
df = sales.loc[
    (sales['family'] == family) &
    (sales['type'] == store_type) 
].drop(columns=['family', 'type', 'store_nbr'])
df.head()
# Out:
#       year_week  unit_sales
# 8578     201301     18312.0
# 8579     201302     11419.0
# 8580     201303     11204.0
# 8581     201304     11211.0
# 8582     201305     13234.0

# %%
df['year'] = df['year_week'].apply(lambda x: int(str(x)[:4])) # 201401 --> 2014
df['week'] = df['year_week'].apply(lambda x: int(str(x)[-2:])) # 201401 --> 1
df.head()
# Out:
#       year_week  unit_sales  year  week
# 8578     201301     18312.0  2013     1
# 8579     201302     11419.0  2013     2
# 8580     201303     11204.0  2013     3
# 8581     201304     11211.0  2013     4
# 8582     201305     13234.0  2013     5

# %%
df['date'] = df['year_week'].apply(lambda x: datetime.strptime(str(x) + '-1', '%Y%W-%w'))
df.set_index('date', inplace=True)
df.sort_index(inplace=True)
df
# Out:
#             year_week  unit_sales  year  week
# date
# 2013-01-07     201301   18312.000  2013     1
# 2013-01-14     201302   11419.000  2013     2
# 2013-01-21     201303   11204.000  2013     3
# 2013-01-28     201304   11211.000  2013     4
# 2013-02-04     201305   13234.000  2013     5
# ...               ...         ...   ...   ...
# 2017-07-17     201729   30704.038  2017    29
# 2017-07-24     201730   34821.180  2017    30
# 2017-07-31     201731   37407.993  2017    31
# 2017-08-07     201732   34445.133  2017    32
# 2017-08-14     201733    9505.218  2017    33
#
# [243 rows x 4 columns]

# %%
df = pd.DataFrame(df.groupby(df.index).sum()['unit_sales']).reset_index()
df.dtypes
# Out:
# date          datetime64[ns]
# unit_sales           float64
# dtype: object

# %%
week_dates_df = pd.read_csv(f'{data_path}/week_dates.csv')
week_dates_df['date'] = pd.to_datetime(week_dates_df['date']) + pd.Timedelta(days=1)
week_dates_df
# Out:
#           date
# 0   2013-01-07
# 1   2013-01-14
# 2   2013-01-21
# 3   2013-01-28
# 4   2013-02-04
# ..         ...
# 256 2017-12-04
# 257 2017-12-11
# 258 2017-12-18
# 259 2017-12-25
# 260 2018-01-01
#
# [261 rows x 1 columns]

# %% [markdown]
# Why are we merging with the `weeks` dataframe?
# (See https://github.com/shiv-io/EDS-I-Group-Project/issues/33)

# %%
df_ts = pd.merge(
    left=week_dates_df,
    right=df,
    left_on='date',
    right_on='date',
    how='left'
)
df_ts
# Out:
#           date  unit_sales
# 0   2013-01-07     18312.0
# 1   2013-01-14     11419.0
# 2   2013-01-21     11204.0
# 3   2013-01-28     11211.0
# 4   2013-02-04     13234.0
# ..         ...         ...
# 256 2017-12-04         NaN
# 257 2017-12-11         NaN
# 258 2017-12-18         NaN
# 259 2017-12-25         NaN
# 260 2018-01-01         NaN
#
# [261 rows x 2 columns]

# %% [markdown]
# No sales data after 2017-08-21:

# %%
df_ts.loc[df_ts['unit_sales'].isna()]
# Out:
#           date  unit_sales
# 241 2017-08-21         NaN
# 242 2017-08-28         NaN
# 243 2017-09-04         NaN
# 244 2017-09-11         NaN
# 245 2017-09-18         NaN
# 246 2017-09-25         NaN
# 247 2017-10-02         NaN
# 248 2017-10-09         NaN
# 249 2017-10-16         NaN
# 250 2017-10-23         NaN
# 251 2017-10-30         NaN
# 252 2017-11-06         NaN
# 253 2017-11-13         NaN
# 254 2017-11-20         NaN
# 255 2017-11-27         NaN
# 256 2017-12-04         NaN
# 257 2017-12-11         NaN
# 258 2017-12-18         NaN
# 259 2017-12-25         NaN
# 260 2018-01-01         NaN

# %% [markdown]
# We'll get rid of the null rows above.

# %%
df_ts = df_ts.loc[df_ts['date']<'2017-08-21']
df_ts
# Out:
#           date  unit_sales
# 0   2013-01-07   18312.000
# 1   2013-01-14   11419.000
# 2   2013-01-21   11204.000
# 3   2013-01-28   11211.000
# 4   2013-02-04   13234.000
# ..         ...         ...
# 236 2017-07-17   30704.038
# 237 2017-07-24   34821.180
# 238 2017-07-31   37407.993
# 239 2017-08-07   34445.133
# 240 2017-08-14    9505.218
#
# [241 rows x 2 columns]

# %% [markdown]
# Let's make sure there are no more nulls.

# %%
# Let's make sure there are no more nulls
assert df_ts['unit_sales'].isna().sum() == 0, 'There are nulls in the data!'

# %%
df = df_ts

# %% [markdown]
# ## Generate time-series features

# %%
df['unit_sales_lag_1'] = df['unit_sales'].shift(1)
df
# Out:
# <ipython-input-20-c46a4f49d0d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unit_sales_lag_1'] = df['unit_sales'].shift(1)
#           date  unit_sales  unit_sales_lag_1
# 0   2013-01-07   18312.000               NaN
# 1   2013-01-14   11419.000         18312.000
# 2   2013-01-21   11204.000         11419.000
# 3   2013-01-28   11211.000         11204.000
# 4   2013-02-04   13234.000         11211.000
# ..         ...         ...               ...
# 236 2017-07-17   30704.038         32572.196
# 237 2017-07-24   34821.180         30704.038
# 238 2017-07-31   37407.993         34821.180
# 239 2017-08-07   34445.133         37407.993
# 240 2017-08-14    9505.218         34445.133
#
# [241 rows x 3 columns]

# %%
df['unit_sales_ma_2_lag_1'] = df['unit_sales'].rolling(2).mean().shift(1)
df
# Out:
# <ipython-input-21-75269a574afb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unit_sales_ma_2_lag_1'] = df['unit_sales'].rolling(2).mean().shift(1)
#           date  unit_sales  unit_sales_lag_1  unit_sales_ma_2_lag_1
# 0   2013-01-07   18312.000               NaN                    NaN
# 1   2013-01-14   11419.000         18312.000                    NaN
# 2   2013-01-21   11204.000         11419.000             14865.5000
# 3   2013-01-28   11211.000         11204.000             11311.5000
# 4   2013-02-04   13234.000         11211.000             11207.5000
# ..         ...         ...               ...                    ...
# 236 2017-07-17   30704.038         32572.196             34593.5595
# 237 2017-07-24   34821.180         30704.038             31638.1170
# 238 2017-07-31   37407.993         34821.180             32762.6090
# 239 2017-08-07   34445.133         37407.993             36114.5865
# 240 2017-08-14    9505.218         34445.133             35926.5630
#
# [241 rows x 4 columns]

# %%
def difference_in_percentage(data, feature):
    # assume data is already sorted
    lag_by_1 = data[feature].shift(1)
    return (data[feature] - lag_by_1)/(lag_by_1)

df['pct_change_lag_1_func'] = difference_in_percentage(df, 'unit_sales')
df
# Out:
# <ipython-input-22-776ec609a614>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pct_change_lag_1_func'] = difference_in_percentage(df, 'unit_sales')
#           date  unit_sales  unit_sales_lag_1  unit_sales_ma_2_lag_1  \
# 0   2013-01-07   18312.000               NaN                    NaN
# 1   2013-01-14   11419.000         18312.000                    NaN
# 2   2013-01-21   11204.000         11419.000             14865.5000
# 3   2013-01-28   11211.000         11204.000             11311.5000
# 4   2013-02-04   13234.000         11211.000             11207.5000
# ..         ...         ...               ...                    ...
# 236 2017-07-17   30704.038         32572.196             34593.5595
# 237 2017-07-24   34821.180         30704.038             31638.1170
# 238 2017-07-31   37407.993         34821.180             32762.6090
# 239 2017-08-07   34445.133         37407.993             36114.5865
# 240 2017-08-14    9505.218         34445.133             35926.5630
#
#      pct_change_lag_1_func
# 0                      NaN
# 1                -0.376420
# 2                -0.018828
# 3                 0.000625
# 4                 0.180448
# ..                     ...
# 236              -0.057354
# 237               0.134091
# 238               0.074288
# 239              -0.079204
# 240              -0.724048
#
# [241 rows x 5 columns]

# %%
df['week'] = df['date'].dt.week
df['week'] = df['week'].astype('int')
df['month'] =df['date'].dt.month
df['year'] = df['date'].dt.year
df
# Out:
# <ipython-input-23-2a8e9fe3ffee>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['date'].dt.week
# <ipython-input-23-2a8e9fe3ffee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['week'] = df['date'].dt.week
# <ipython-input-23-2a8e9fe3ffee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['week'] = df['week'].astype('int')
# <ipython-input-23-2a8e9fe3ffee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] =df['date'].dt.month
# <ipython-input-23-2a8e9fe3ffee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['date'].dt.year
#           date  unit_sales  unit_sales_lag_1  unit_sales_ma_2_lag_1  \
# 0   2013-01-07   18312.000               NaN                    NaN
# 1   2013-01-14   11419.000         18312.000                    NaN
# 2   2013-01-21   11204.000         11419.000             14865.5000
# 3   2013-01-28   11211.000         11204.000             11311.5000
# 4   2013-02-04   13234.000         11211.000             11207.5000
# ..         ...         ...               ...                    ...
# 236 2017-07-17   30704.038         32572.196             34593.5595
# 237 2017-07-24   34821.180         30704.038             31638.1170
# 238 2017-07-31   37407.993         34821.180             32762.6090
# 239 2017-08-07   34445.133         37407.993             36114.5865
# 240 2017-08-14    9505.218         34445.133             35926.5630
#
#      pct_change_lag_1_func  week  month  year
# 0                      NaN     2      1  2013
# 1                -0.376420     3      1  2013
# 2                -0.018828     4      1  2013
# 3                 0.000625     5      1  2013
# 4                 0.180448     6      2  2013
# ..                     ...   ...    ...   ...
# 236              -0.057354    29      7  2017
# 237               0.134091    30      7  2017
# 238               0.074288    31      7  2017
# 239              -0.079204    32      8  2017
# 240              -0.724048    33      8  2017
#
# [241 rows x 8 columns]

# %%
df.iloc[:,0:]
# Out:
#           date  unit_sales  unit_sales_lag_1  unit_sales_ma_2_lag_1  \
# 0   2013-01-07   18312.000               NaN                    NaN
# 1   2013-01-14   11419.000         18312.000                    NaN
# 2   2013-01-21   11204.000         11419.000             14865.5000
# 3   2013-01-28   11211.000         11204.000             11311.5000
# 4   2013-02-04   13234.000         11211.000             11207.5000
# ..         ...         ...               ...                    ...
# 236 2017-07-17   30704.038         32572.196             34593.5595
# 237 2017-07-24   34821.180         30704.038             31638.1170
# 238 2017-07-31   37407.993         34821.180             32762.6090
# 239 2017-08-07   34445.133         37407.993             36114.5865
# 240 2017-08-14    9505.218         34445.133             35926.5630
#
#      pct_change_lag_1_func  week  month  year
# 0                      NaN     2      1  2013
# 1                -0.376420     3      1  2013
# 2                -0.018828     4      1  2013
# 3                 0.000625     5      1  2013
# 4                 0.180448     6      2  2013
# ..                     ...   ...    ...   ...
# 236              -0.057354    29      7  2017
# 237               0.134091    30      7  2017
# 238               0.074288    31      7  2017
# 239              -0.079204    32      8  2017
# 240              -0.724048    33      8  2017
#
# [241 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:,2:]
y = df['unit_sales']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
model_name = f"XBG_Time_Series_Store_{store_type}_{family}_Lagged_Features"
max_depth = 100
early_stopping_round = 50
# with mlflow.start_run(run_name=model_name):
model = XGBRegressor(
        max_depth=max_depth,
        early_stopping_round=early_stopping_round,
        n_jobs=-1)
# evaluate the model
cv = RepeatedKFold(n_splits=2, n_repeats=1, random_state=0)
n_scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_percentage_error', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('MAPE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# mlflow.log_metric("MAPE", abs(mean(n_scores)))
# mlflow.log_param("early_stopping_round", early_stopping_round)
# mlflow.log_param("max_depth", max_depth)
model.fit(X_train, y_train)
# mlflow.xgboost.log_model(model, model_name)
# try:
#     mlflow.xgboost.save_model(model, path=f'/Users/sg/projects/EDS-I-Group-Project/models/{model_name}')
# except mlflow.exceptions.MlflowException:
#     print("Model directory already exists, model will not be saved.")
# Out:
# MAPE: -0.065 (0.004)
# [22:52:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { early_stopping_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, early_stopping_round=50,
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=100, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=-1,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
model.fit(X_train, y_train)
plot_importance(model)
# Out:
# [22:52:48] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { early_stopping_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

# %%
shap.summary_plot(shap_values, X)

# %% [markdown]
# ## Seasonality Calculation

# %%
df_seasonality = df.copy()
df_seasonality['unit_sales_ma_4_lag_1'] = df_seasonality['unit_sales'].rolling(4).mean().shift(1)
df_seasonality.dropna(inplace=True)
df_seasonality
# Out:
#           date  unit_sales  unit_sales_lag_1  unit_sales_ma_2_lag_1  \
# 4   2013-02-04   13234.000         11211.000             11207.5000
# 5   2013-02-11   14028.000         13234.000             12222.5000
# 6   2013-02-18   12678.000         14028.000             13631.0000
# 7   2013-02-25   12279.000         12678.000             13353.0000
# 8   2013-03-04   13965.000         12279.000             12478.5000
# ..         ...         ...               ...                    ...
# 236 2017-07-17   30704.038         32572.196             34593.5595
# 237 2017-07-24   34821.180         30704.038             31638.1170
# 238 2017-07-31   37407.993         34821.180             32762.6090
# 239 2017-08-07   34445.133         37407.993             36114.5865
# 240 2017-08-14    9505.218         34445.133             35926.5630
#
#      pct_change_lag_1_func  week  month  year  unit_sales_ma_4_lag_1
# 4                 0.180448     6      2  2013            13036.50000
# 5                 0.059997     7      2  2013            11767.00000
# 6                -0.096236     8      2  2013            12419.25000
# 7                -0.031472     9      2  2013            12787.75000
# 8                 0.137308    10      3  2013            13054.75000
# ..                     ...   ...    ...   ...                    ...
# 236              -0.057354    29      7  2017            34177.35050
# 237               0.134091    30      7  2017            34169.38925
# 238               0.074288    31      7  2017            33678.08425
# 239              -0.079204    32      8  2017            33876.35175
# 240              -0.724048    33      8  2017            34344.58600
#
# [237 rows x 9 columns]

# %%
# Calculate seasonality
df_seasonality['sv'] = df_seasonality['unit_sales_ma_4_lag_1'] - df_seasonality['unit_sales']

# Plot it
df_seasonality.set_index('date')['sv'].plot(figsize=(15,8), title='Seasonal variation from 4-week moving average')
# Out:
# <AxesSubplot:title={'center':'Seasonal variation from 4-week moving average'}, xlabel='date'>

# %% [markdown]
# ### Deepchecks

# %%
from deepchecks import Dataset
from deepchecks.suites import full_suite
ds_train = X_train.merge(y_train, left_index=True, right_index=True)
ds_test = X_test.merge(y_test, left_index=True, right_index=True)
ds_train = Dataset(ds_train)
ds_test =  Dataset(ds_test)
suite = full_suite()
results = suite.run(train_dataset=ds_train, test_dataset=ds_test, model=model)
results
# Out:
# /Users/tehuttesfayebiru/opt/anaconda3/lib/python3.8/site-packages/deepchecks/__init__.py:141: DeprecationWarning:
#
# Ability to import base tabular functionality from the `deepchecks` package directly is deprecated, please import from `deepchecks.tabular` instead
# Full Suite:   0%|          | 0/35 [00:00<?, ? Check/s]
# /Users/tehuttesfayebiru/opt/anaconda3/lib/python3.8/site-packages/deepchecks/utils/features.py:106: UserWarning:
#
# Features importance was not calculated:
# Got error when trying to predict with model on dataset: feature_names mismatch: ['unit_sales_lag_1', 'unit_sales_ma_2_lag_1', 'pct_change_lag_1_func', 'week', 'month', 'year'] ['unit_sales_lag_1', 'unit_sales_ma_2_lag_1', 'pct_change_lag_1_func', 'week', 'month', 'year', 'unit_sales']
# training data did not have the following fields: unit_sales
# VBox(children=(HTML(value='\n        <h1 id="summary_T0MVD">Full Suite</h1>\n        <p>\n            The suit…

# %%
result_json = results.to_json()
result_json
# Out:
# '{"name": "Full Suite", "results": ["{\\"name\\": \\"Model Info\\", \\"params\\": {}, \\"header\\": \\"Model Info\\", \\"summary\\": \\"Summarize given model parameters.\\", \\"display\\": [[\\"str\\", \\"Got error when trying to predict with model on dataset: feature_names mismatch: [\'unit_sales_lag_1\', \'unit_sales_ma_2_lag_1\', \'pct_change_lag_1_func\', \'week\', \'month\', \'year\'] [\'unit_sales_lag_1\', \'unit_sales_ma_2_lag_1\', \'pct_change_lag_1_func\', \'week\', \'month\', \'year\', \'unit_sales\']\\\\ntraining data did not have the following fields: unit_sales\\"]]}", "{\\"name\\": \\"Columns Info\\", \\"params\\": {\\"n_top_columns\\": 10}, \\"header\\": \\"Columns Info - Train Dataset\\", \\"summary\\": \\"Return the role and logical type of each column.\\", \\"value\\": {\\"unit_sales_lag_1\\": \\"numerical feature\\", \\"unit_sales_ma_2_lag_1\\": \\"numerical feature\\", \\"pct_change_lag_1_func\\": \\"numerical feature\\", \\"week\\": \\"numerical feature\\", \\"month\\": \\"numerical feature\\", \\"year\\": \\"numerical feature\\", \\"unit_sales\\": \\"numerical feature\\"}, \\"display\\": [[\\"html\\", \\"* showing only the top 10 columns, you can change it using n_top_columns param\\"], [\\"dataframe\\", \\"[{\\\\\\"unit_sales_lag_1\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"unit_sales_ma_2_lag_1\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"pct_change_lag_1_func\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"week\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"month\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"year\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"unit_sales\\\\\\":\\\\\\"numerical feature\\\\\\"}]\\"]]}", "{\\"name\\": \\"Columns Info\\", \\"params\\": {\\"n_top_columns\\": 10}, \\"header\\": \\"Columns Info - Test Dataset\\", \\"summary\\": \\"Return the role and logical type of each column.\\", \\"value\\": {\\"unit_sales_lag_1\\": \\"numerical feature\\", \\"unit_sales_ma_2_lag_1\\": \\"numerical feature\\", \\"pct_change_lag_1_func\\": \\"numerical feature\\", \\"week\\": \\"numerical feature\\", \\"month\\": \\"numerical feature\\", \\"year\\": \\"numerical feature\\", \\"unit_sales\\": \\"numerical feature\\"}, \\"display\\": [[\\"html\\", \\"* showing only the top 10 columns, you can change it using n_top_columns param\\"], [\\"dataframe\\", \\"[{\\\\\\"unit_sales_lag_1\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"unit_sales_ma_2_lag_1\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"pct_change_lag_1_func\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"week\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"month\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"year\\\\\\":\\\\\\"numerical feature\\\\\\",\\\\\\"unit_sales\\\\\\":\\\\\\"numerical feature\\\\\\"}]\\"]]}", "{\\"name\\": \\"Confusion Matrix Report\\", \\"params\\": {}, \\"header\\": \\"Confusion Matrix Report - Train Dataset\\", \\"summary\\": \\"Calculate the confusion matrix of the model on the given dataset.\\", \\"display\\": [[\\"str\\", \\"Got error when trying to predict with model on dataset: feature_names mismatch: [\'unit_sales_lag_1\', \'unit_sales_ma_2_lag_1\', \'pct_change_lag_1_func\', \'week\', \'month\', \'year\'] [\'unit_sales_lag_1\', \'unit_sales_ma_2_lag_1\', \'pct_change_lag_1_func\', \'week\', \'month\', \'year\', \'unit_sales\']\\\\ntraining data did not have the following fields: unit_sales\\"]]}", "{\\"name\\": \\"Confusion Matrix Report\\", \\"params\\": {}, \\"header\\": \\"Confusion Matrix Report - Test Dataset\\", \\"summary\\": \\"Calculate the confusion matrix of the model on the given dataset.\\", \\"display\\": [[\\"str\\", \\"Got error when trying to predict with model on dataset: feature_names mismatch: [\'unit_sales_lag_1\', \'unit_sales_ma_2_lag_1\', \'pct_change_lag_1_func\', \'week\', \'month\', \'year\'] [\'unit_sales_lag_1\', \'unit_sales_ma_2_lag_1\', \'pct_change_lag_1_func\', \'week\', \'month\', \'year\', \'unit_sales\']\\\\ntraining data did not have the following fields: unit_sales\\"] ...
